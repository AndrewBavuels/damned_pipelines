# %% [markdown]
# # First of all...remember the imports!!!
#
# Ohhhh...Python is so easy and nice 'cause there's always someone else doing the hard stuff...
#
# ![Image](../images/import.jpg)

# %%
import requests
import pandas as pd
import re
import json
import math
import os
from dotenv import load_dotenv

# %% [markdown]
# # ...and remenber to leave everything nice and tidy...
#
# ![Image](../images/spaghetti.jpg)

# %%
load_dotenv("./.env")
TOKEN = os.environ.get("API_TOKEN")

# %%
API_TOKEN = TOKEN #API TOKEN (REMEMBER: do not push these to your repo) # Tocar
USERNAME = 'AndrewBavuels/' #USERNAME # Tocar
BASE_URL = 'https://api.github.com/'
KEY = 'repos/'
OWNER = 'ih-datapt-mad/'
REPO = 'dataptmad0923_labs/' # Tocar
SEARCH = 'search/issues?q=repo:'+OWNER+REPO+'+type:pr+state:{}'
PULLS = 'pulls?page={}&per_page=100&state={}'
COMMITS = 'pulls/{}/commits'
STATE = 'open'

# %%
BASE_URL + KEY + OWNER + REPO + PULLS
# Out:
# 'https://api.github.com/repos/ih-datapt-mad/dataptmad0923_labs/pulls?page={}&per_page=100&state={}'

# %%
field_list1 = ['number',
               'title',
               'state',
               'created_at',
               'updated_at',
               'closed_at',
               'html_url',
               'base.repo.full_name',
               'base.ref',
               'head.repo.full_name',
               'head.ref',
               'head.repo.pushed_at']

# %%
field_list2 = ['student_name',
               'number',
               'lab_name',
               'state',
               'lab_status',
               'created_at',
               'updated_at',
               'closed_at',
               'html_url',
               'base.repo.full_name',
               'base.ref',
               'head.repo.full_name',
               'head.ref',
               'head.repo.pushed_at']

# %%
field_sort1 = ['lab_status',
               'lab_name',
               'student_name']

# %%
field_name1 = ['Student Name',
               'PR Number',
               'Lab Name',
               'PR Status',
               'Lab Status',
               'PR Created at',
               'PR Updated at',
               'PR Closed at',
               'PR URL',
               'base repository',
               'base',
               'head repository',
               'compare',
               'Pushed at']

# %% [markdown]
# # Functions
#
# Here you may find all functions you need to create your Pipeline. Be sure you test them before you start to build your Pipeline.
#
# ![Image](../images/pieces.jpg)

# %% [markdown]
# ### Auxiliary Functions

# %%
# Aux Function 1: You can get only 100 results per page so it is important to know the number of pages you'll need.

def pages(base_url, search, state, username, api_token):
    pages = requests.get(base_url + search.format(state), auth=(username,api_token)).json()['total_count']
    if STATE == 'open':
        pages = math.ceil(pages/100)
        return pages
    elif STATE == 'closed':
        pages = math.ceil(pages/100)
        return pages

# %%
# Auc Function 2: Check the committs in order to know which labs are ready to be reviewed.

def get_commits(base_url, key, owner, repo, commits, pull, username, api_token):
    r_commits = requests.get(base_url + key + owner + repo + commits.format(pull),
                             auth=(username, api_token)).json()
    df_commits = pd.json_normalize(r_commits)
    list_commits = list(df_commits['commit.message'])
    commit = list(set([commit if commit == 'lab-finished' else 'lab-started' for commit in list_commits]))
    if 'lab-finished' in commit:
        return 'lab-finished'
    else:
        return 'lab-started'

# %%
# Aux Function 3: But the students aren't careful with the naming...

def student_name(x):
    if ']' in x:
        x = x.split(']')
        x = x[1].replace('_', ' ').strip()
        len_x = len(x.split(' '))
        if len_x > 1:
            x = re.findall('\w[a-zA-Z áéíóúÁÉÍÓÚñÑ-]+', x)
            x = x[0].strip()
            return x
        else:
            x = 'No student name provided'
            return x
    else:
        x = 'Pull request is not properly named'
        return x

# %%
#Aux Function 4

def lab_name(x):
    if ']' in x:
        x = x.split(']')
        x = x[0] + ']'
        x = x.strip()
        lower_case = re.findall('[A-ZÁÉÍÓÚñÑ]+', x)
        if x[0] == '[' and x[-1] == ']' and ' ' not in x and len(lower_case) == 0:
            return x
        else:
            x = 'Lab format name is incorrect'
            return x
    else:
        x = 'Pull request is not properly named'
        return x

# %%
# Aux Function 5: ...or forget to push their work!!!

def time_parser(x):
    try:
        x = x.strip()
        x = re.findall('[0-9]+', x)
        x = ''.join(x)
        x = pd.to_datetime(x, format='%Y%m%d%H%M%S', errors='coerce')
        return x
    except:
        return 'Nothing pushed yet'

# %% [markdown]
# ### Pipeline Functions

# %%
# Pipeline Function 1: And finally get the 'pull requests'.

def get_pulls(base_url, key, owner, repo, pulls, search, state, username, api_token, field_list):
    pulls_list = []
    max_pages = pages(base_url, search, state, username, api_token)
    for i in range(max_pages):
        r_pulls = requests.get(base_url + key + owner + repo + pulls.format(i+1, state),
                               auth=(username, api_token)).json()
        df_pulls = pd.json_normalize(r_pulls)
        pulls_list.append(df_pulls)
    df_pulls = pd.concat(pulls_list)
    df_pulls = df_pulls[field_list]
    return df_pulls

# %%
# Pipeline Function 2: Apply!!!!!!

def df_status(df_pulls, base_url, key, owner, repo, commits, username, api_token, field_list):
    df_pulls['student_name'] = df_pulls['title'].apply(student_name)
    df_pulls['lab_name'] = df_pulls['title'].apply(lab_name)
    df_pulls['created_at'] = df_pulls['created_at'].apply(time_parser)
    df_pulls['updated_at'] = df_pulls['updated_at'].apply(time_parser)
    df_pulls['head.repo.pushed_at'] = df_pulls['head.repo.pushed_at'].apply(time_parser)
    df_pulls['lab_status'] = df_pulls.apply(lambda col: get_commits(base_url,
                                                                    key,
                                                                    owner,
                                                                    repo,
                                                                    commits,
                                                                    col['number'],
                                                                    username,
                                                                    api_token), axis=1)
    df_status = df_pulls[field_list]
    return df_status

# %%
# Pipeline function 3: And there you have it!!!

def create_csv(df_status, field_sort, field_name):
    df_csv = df_status.sort_values(by=field_sort, ascending=False)
    df_csv.columns = field_name
    df_csv.to_csv('../data/labs_status.csv', index=False)
    return df_csv

# %%
# Damned Pipelines!!!

DF_PULLS = get_pulls(BASE_URL, KEY, OWNER, REPO, PULLS, SEARCH, STATE, USERNAME, API_TOKEN, field_list1)
DF_STATUS = df_status(DF_PULLS, BASE_URL, KEY, OWNER, REPO, COMMITS, USERNAME, API_TOKEN, field_list2)
DF_CSV = create_csv(DF_STATUS, field_sort1, field_name1)
DF_CSV
# Out:
#                           Student Name  PR Number  \
# 21                         Tomas Morin        202
# 23                      Alana Castillo        189
# 9                       Alberto Castro        286
# 0                          Tomas Morin        295
# 24                         Tomas Morin        187
# 33                      Alana Castillo         73
# 34                      Natalia Vargas         69
# 26            No student name provided        171
# 28            No student name provided        165
# 30                          John Bryan        160
# 29                         Elena Luque        164
# 27                      Andrew Bavuels        168
# 25                          John Bryan        176
# 12            No student name provided        276
# 13            No student name provided        271
# 16            No student name provided        265
# 32            No student name provided         91
# 8                       Alberto Castro        287
# 7                       Rodrigo Coloma        288
# 11                      Andrew Bavuels        282
# 14            No student name provided        269
# 4                           Ana Aguiar        291
# 18                         Tomas Morin        258
# 22                          John Bryan        199
# 3                       Carlos Sanchez        292
# 2                           Ana Aguiar        293
# 10  Pull request is not properly named        285
# 5             No student name provided        290
# 15            No student name provided        268
# 17            No student name provided        259
# 19            No student name provided        251
# 1                       Carlos Sanchez        294
# 20                      Alana Castillo        228
# 31                      Alana Castillo        155
# 6             No student name provided        289
#
#                               Lab Name PR Status    Lab Status  \
# 21   [understanding-descriptive-stats]      open   lab-started
# 23   [understanding-descriptive-stats]      open   lab-started
# 9            [resolving-git-conflicts]      open   lab-started
# 0                              [mysql]      open   lab-started
# 24                [matplotlib-seaborn]      open   lab-started
# 33                 [map-reduce_filter]      open   lab-started
# 34                 [map-reduce-filter]      open   lab-started
# 26                  [lab-web-scraping]      open   lab-started
# 28                  [lab-web-scraping]      open   lab-started
# 30                  [lab-web-scraping]      open   lab-started
# 29                  [lab-web-scraping]      open   lab-started
# 27                  [lab-web-scraping]      open   lab-started
# 25            [lab-matplotlib-seaborn]      open   lab-started
# 12     [lab-intro-recommender-systems]      open   lab-started
# 13     [lab-intro-recommender-systems]      open   lab-started
# 16     [lab-intro-recommender-systems]      open   lab-started
# 32                [lab-error-handling]      open   lab-started
# 8                 [lab-error-handling]      open   lab-started
# 7                        [intro-to-ml]      open   lab-started
# 11                       [intro-to-ml]      open   lab-started
# 14         [intro-recommender-systems]      open   lab-started
# 4          [intro-recommender-systems]      open   lab-started
# 18                  [intro-bi-tableau]      open   lab-started
# 22                [hypothesis-testing]      open   lab-started
# 3            [data-cleaning-challenge]      open   lab-started
# 2            [data-cleaning-challenge]      open   lab-started
# 10  Pull request is not properly named      open   lab-started
# 5         Lab format name is incorrect      open   lab-started
# 15        Lab format name is incorrect      open   lab-started
# 17        Lab format name is incorrect      open   lab-started
# 19        Lab format name is incorrect      open   lab-started
# 1         Lab format name is incorrect      open   lab-started
# 20        Lab format name is incorrect      open   lab-started
# 31        Lab format name is incorrect      open   lab-started
# 6                         [bi-tableau]      open  lab-finished
#
#          PR Created at       PR Updated at PR Closed at  \
# 21 2023-12-12 17:57:12 2023-12-12 17:57:12         None
# 23 2023-12-06 17:10:14 2023-12-12 19:09:35         None
# 9  2024-02-03 22:08:54 2024-02-03 22:08:54         None
# 0  2024-02-05 13:43:27 2024-02-05 13:43:27         None
# 24 2023-12-05 12:57:25 2024-01-22 12:44:31         None
# 33 2023-10-07 13:11:16 2024-01-11 20:51:38         None
# 34 2023-10-07 13:03:06 2023-10-07 13:03:06         None
# 26 2023-11-07 12:16:27 2023-11-07 12:16:27         None
# 28 2023-11-04 13:18:38 2024-02-03 22:32:34         None
# 30 2023-11-04 13:10:43 2024-01-21 11:23:45         None
# 2   https://github.com/ih-datapt-mad/dataptmad0923...
# 10  https://github.com/ih-datapt-mad/dataptmad0923...
# 5   https://github.com/ih-datapt-mad/dataptmad0923...
# 15  https://github.com/ih-datapt-mad/dataptmad0923...
# 17  https://github.com/ih-datapt-mad/dataptmad0923...
# 19  https://github.com/ih-datapt-mad/dataptmad0923...
# 1   https://github.com/ih-datapt-mad/dataptmad0923...
# 20  https://github.com/ih-datapt-mad/dataptmad0923...
# 31  https://github.com/ih-datapt-mad/dataptmad0923...
# 6   https://github.com/ih-datapt-mad/dataptmad0923...
#
#                      base repository  base  \
# 21  ih-datapt-mad/dataptmad0923_labs  main
# 23  ih-datapt-mad/dataptmad0923_labs  main
# 9   ih-datapt-mad/dataptmad0923_labs  main
# 0   ih-datapt-mad/dataptmad0923_labs  main
# 24  ih-datapt-mad/dataptmad0923_labs  main
# 33  ih-datapt-mad/dataptmad0923_labs  main
# 34  ih-datapt-mad/dataptmad0923_labs  main
# 26  ih-datapt-mad/dataptmad0923_labs  main
# 28  ih-datapt-mad/dataptmad0923_labs  main
# 30  ih-datapt-mad/dataptmad0923_labs  main
# 29  ih-datapt-mad/dataptmad0923_labs  main
# 27  ih-datapt-mad/dataptmad0923_labs  main
# 25  ih-datapt-mad/dataptmad0923_labs  main
# 12  ih-datapt-mad/dataptmad0923_labs  main
# 13  ih-datapt-mad/dataptmad0923_labs  main
# 16  ih-datapt-mad/dataptmad0923_labs  main
# 32  ih-datapt-mad/dataptmad0923_labs  main
# 8   ih-datapt-mad/dataptmad0923_labs  main
# 7   ih-datapt-mad/dataptmad0923_labs  main
# 11  ih-datapt-mad/dataptmad0923_labs  main
# 14  ih-datapt-mad/dataptmad0923_labs  main
# 4   ih-datapt-mad/dataptmad0923_labs  main
# 18  ih-datapt-mad/dataptmad0923_labs  main
# 22  ih-datapt-mad/dataptmad0923_labs  main
# 3   ih-datapt-mad/dataptmad0923_labs  main
# 2   ih-datapt-mad/dataptmad0923_labs  main
# 10  ih-datapt-mad/dataptmad0923_labs  main
# 5   ih-datapt-mad/dataptmad0923_labs  main
# 15  ih-datapt-mad/dataptmad0923_labs  main
# 17  ih-datapt-mad/dataptmad0923_labs  main
# 19  ih-datapt-mad/dataptmad0923_labs  main
# 1   ih-datapt-mad/dataptmad0923_labs  main
# 20  ih-datapt-mad/dataptmad0923_labs  main
# 31  ih-datapt-mad/dataptmad0923_labs  main
# 6   ih-datapt-mad/dataptmad0923_labs  main
#
#                             head repository                           compare  \
# 21          tomasmorin97/dataptmad0923_labs   understanding-descriptive-stats
# 23         AlanaCastillo/dataptmad0923_labs   understanding-descriptive-stats
# 9          castroalberto/dataptmad0923_labs       lab-resolving-git-conflicts
# 0           tomasmorin97/dataptmad0923_labs                             mysql
# 24          tomasmorin97/dataptmad0923_labs                matplotlib-seaborn
# 33         AlanaCastillo/dataptmad0923_labs                 map-reduce-filter
# 34       nataliavargas13/dataptmad0923_labs                 map-reduce-filter
# 26          Guillemorato/dataptmad0923_labs                  lab-web-scraping
